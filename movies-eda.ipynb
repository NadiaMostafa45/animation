# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/imdb-movie-insights/IMDB_Movie_Insights.csv

# %%
import pandas as pd

import seaborn as sns

# Load the dataset
df = pd.read_csv('/kaggle/input/imdb-movie-insights/IMDB_Movie_Insights.csv')
df
# Out:
#                              movie_name  Year  Age  Duration(minutes)  \
# 0                 De trei ori Bucuresti  1967   15                 96
# 1          Ein Mann geht durch die Wand  1959   15                 99
# 2                 Once Upon a Scoundrel  1973   15                 99
# 3                            Extraction  2012   15                 89
# 4                  Tomorrow You're Gone  2012   15                 93
# ...                                 ...   ...  ...                ...
# 1959                          Good Time  2017   15                102
# 1960                  Irreplaceable You  2018   15                 96
# 1961               In Search of Fellini  2017   15                 93
# 1962                       Lady Macbeth  2016   15                 89
# 1963  Film Stars Don't Die in Liverpool  2017   15                105
#
#       Ratings  Gross Profit($M)    Votes
# 0         7.0              2.46       50
# 1         6.9              2.46      323
# ...

# %%
# Display basic information
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1964 entries, 0 to 1963
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_name         1964 non-null   object
#  1   Year               1964 non-null   int64
#  2   Age                1964 non-null   int64
#  3   Duration(minutes)  1964 non-null   int64
#  4   Ratings            1964 non-null   float64
#  5   Gross Profit($M)   1964 non-null   float64
#  6   Votes              1963 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 107.5+ KB
# None

# %%
# Display basic information
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1964 entries, 0 to 1963
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_name         1964 non-null   object
#  1   Year               1964 non-null   int64
#  2   Age                1964 non-null   int64
#  3   Duration(minutes)  1964 non-null   int64
#  4   Ratings            1964 non-null   float64
#  5   Gross Profit($M)   1964 non-null   float64
#  6   Votes              1963 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 107.5+ KB
# None

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# movie_name           0
# Year                 0
# Age                  0
# Duration(minutes)    0
# Ratings              0
# Gross Profit($M)     0
# Votes                1
# dtype: int64

# %%
# Descriptive statistics
print(df.describe())
# Out:
#               Year          Age  Duration(minutes)      Ratings  \
# count  1964.000000  1964.000000        1964.000000  1964.000000
# mean   2012.794807    14.799389         105.851324     6.486354
# std       6.957198     1.302640          16.984434     0.852157
# min    1933.000000    12.000000          22.000000     3.100000
# 25%    2013.000000    15.000000          94.000000     5.900000
# 50%    2014.000000    15.000000         103.000000     6.500000
# 75%    2016.000000    15.000000         116.000000     7.100000
# max    2020.000000    18.000000         201.000000     8.700000
#
#        Gross Profit($M)
# count       1964.000000
# mean          24.862714
# std           66.285029
# min            0.000000
# 25%            0.440000
# 50%            2.460000
# 75%           14.035000
# max          936.660000

# %%
# Display the column names in the DataFrame
print(df.columns)
# Out:
# Index(['movie_name', 'Year', 'Age', 'Duration(minutes)', 'Ratings',
#        'Gross Profit($M)', 'Votes'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
sns.histplot(df['Age'], bins=30, kde=True)
plt.title('Distribution of Age')
plt.show()

# %%
sns.histplot(df['Duration(minutes)'], bins=30, kde=True)
plt.title('Distribution of Duration(minutes)')
plt.show()

# %%
sns.scatterplot(x='Ratings', y='Gross Profit($M)', data=df)
plt.title('Rating vs Gross Profit')
plt.show()

# %%
sns.histplot(df['Votes'], bins=30, kde=True)
plt.title('Distribution of Votes')
plt.show()

# %%
sns.pairplot(df[['movie_name', 'Year', 'Age', 'Duration(minutes)', 'Ratings',
       'Gross Profit($M)', 'Votes']])
plt.show()

# %%
sns.histplot(df['Year'], bins=30, kde=True)
plt.title('Distribution of Year')
plt.show()
